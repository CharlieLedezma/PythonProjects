# %%
import numpy as np
import matplotlib.pyplot as plt
import control as co

# %%
GA = co.tf([1],[1,2,1])
GB = co.tf([1],[1, 0.4, 1])
GC = co.tf([1],[1, 5, 1])
GD = co.tf([1],[1, 1, 1])

# %%
t = np.linspace(0, 10, 1000)
t, y = co.step_response(GA)
plt.plot(t,y)
plt.grid()

# %%
t = np.linspace(0, 10, 1000)
t, y = co.step_response(GB)
plt.plot(t,y)
plt.grid()

# %%
t = np.linspace(0, 10, 1000)
t, y = co.step_response(GC)
plt.plot(t,y)
plt.grid()

# %%
t = np.linspace(0, 10, 1000)
t, y = co.step_response(GD)
plt.plot(t,y)
plt.grid()

# %%
co.step_info(GA)
# Out:
# {'RiseTime': 3.349214680718612,
#  'SettlingTime': 5.861125691257571,
#  'SettlingMin': 0.9013985555006366,
#  'SettlingMax': 0.9920922447210146,
#  'Overshoot': 0,
#  'Undershoot': 0,
#  'Peak': 0.9920922447210146,
#  'PeakTime': 6.907755278982137,
#  'SteadyStateValue': 1.0}

# %%
co.step_info(GB)
# Out:
# {'RiseTime': 1.25140494184459,
#  'SettlingTime': 19.77219808114452,
#  'SettlingMin': 0.7238941428845118,
#  'SettlingMax': 1.5260358403692005,
#  'Overshoot': 52.60358403692005,
#  'Undershoot': 0,
#  'Peak': 1.5260358403692005,
#  'PeakTime': 3.2536528487959337,
#  'SteadyStateValue': 1.0}

# %%
co.step_info(GC)
# Out:
# {'RiseTime': 10.363720823916116,
#  'SettlingTime': 19.05587377300705,
#  'SettlingMin': 0.9024921489598664,
#  'SettlingMax': 0.9989544552744066,
#  'Overshoot': 0,
#  'Undershoot': 0,
#  'Peak': 0.9989544552744066,
#  'PeakTime': 33.097043921538564,
#  'SteadyStateValue': 1.0}

# %%
co.step_info(GD)
# Out:
# {'RiseTime': 1.674607340359306,
#  'SettlingTime': 8.093935478403314,
#  'SettlingMin': 0.9394891622475171,
#  'SettlingMax': 1.1630334929041957,
#  'Overshoot': 16.30334929041957,
#  'Undershoot': 0,
#  'Peak': 1.1630334929041957,
#  'PeakTime': 3.62831590411183,
#  'SteadyStateValue': 1.0}

# %%
co.dcgain(GA)
# Out:
# 1.0

# %%
co.dcgain(GB)
# Out:
# 1.0

# %%
co.dcgain(GC)
# Out:
# 1.0

# %%
co.dcgain(GD)
# Out:
# 1.0
