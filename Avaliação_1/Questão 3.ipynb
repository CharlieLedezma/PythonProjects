# %%
import numpy as np
import matplotlib.pyplot as plt
import control as co
from scipy import signal

# %%
G1 = co.tf([3],[8,12,26,18,0])
G1
# Out:
# TransferFunction(array([3]), array([ 8, 12, 26, 18,  0]))

# %%
G2 = co.feedback(G1, 1)
G2
# Out:
# TransferFunction(array([3]), array([ 8, 12, 26, 18,  3]))

# %%
#Resposta em malha fechada
t = np.linspace(0, 5, 1000)
t, y = co.step_response(G2)
plt.plot(t, y)
plt.xlabel('time (s)')
plt.ylabel('Amplitude')
plt.title('impulse response')
plt.grid()

# %%
#ganho em DC
co.dcgain(G16)
# Out:
# 1.0

# %%
t= np.linspace(0, 1, 1000, endpoint=False)

plt.plot(t, signal.square(2*np.pi*10*t))
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Sinal Quadrado')
plt.grid()
